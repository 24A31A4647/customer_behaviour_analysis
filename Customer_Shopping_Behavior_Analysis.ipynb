# %%
import pandas as pd
df = pd.read_csv('customer_shopping_behavior.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('customer_shopping_behavior.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df=pd.read_csv("customer_shopping_behavior.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("customer_shopping_behavior.csv")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('customer_shopping_behavior.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('customer_shopping_behavior.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\YOUR_USERNAME\Downloads\customer_shopping_behavior.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r"C:\Users\YOUR_USERNAME\Downloads\customer_shopping_behavior.csv")
#
# ...

# %%
customer_shopping_behavior.csv

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\YOUR_USERNAME\Downloads\customer_shopping_behavior.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r"C:\Users\YOUR_USERNAME\Downloads\customer_shopping_behavior.csv")
#
# ...

# %%
import pandas as pd
df = pd.read_csv('customer_shopping_behavior.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('customer_shopping_behavior.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os 
print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.continuum', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.virtual_documents', '.vscode', '24a31a4647', 'add.py', 'app.py', 'AppData', 'Application Data', 'audio', 'audio.py', 'Contacts', 'Cookies', 'Customer_Shopping_Behavior_Analysis.ipynb', 'Documents', 'Downloads', 'Dropbox', 'Favorites', 'Links', 'Local Settings', 'Microsoft', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TM.blf', 'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'tcs', 'Templates', 'Untitled-1.powerbi.txt', 'Untitled-1.txt', 'Untitled.ipynb', 'Videos', 'vscode projects', 'WPS Cloud Files', 'WPSDrive']

# %%
import os
os.chdir("Downloads")

# %%
import pandas as pd
pd.read_csv("customer_shopping_behavior.csv")
df.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 import pandas as pd
#       2 pd.read_csv("customer_shopping_behavior.csv")
# ----> 3 df.head
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv("customer_shopping_behavior.csv")
df.head
# Out:
# <bound method NDFrame.head of       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
import pandas as pd
df=pd.read_csv("customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe(include="all")
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace('  ', '_ ')
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.columns
# Out:
# Index(['customer id', 'age', 'gender', 'item purchased', 'category',
#        'purchase amount (usd)', 'location', 'size', 'color', 'season',
#        'review rating', 'subscription status', 'shipping type',
#        'discount applied', 'promo code used', 'previous purchases',
#        'payment method', 'frequency of purchases'],
#       dtype='object')

# %%
labels=["Young Adult","Adult,"Middle-aged","senior"]
d["age-group"]=pd.cut(df["age"],q=4,labels=labels)
# Out:
#   Cell In[20], line 1
#     labels=["Young Adult","Adult,"Middle-aged","senior"]
#                                                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
labels=["Young Adult","Adult","Middle-aged","senior"]
d["age-group"]=pd.cut(df["age"],q=4,labels=labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 labels=["Young Adult","Adult","Middle-aged","senior"]
# ----> 2 d["age-group"]=pd.cut(df["age"],q=4,labels=labels)
#
# TypeError: cut() got an unexpected keyword argument 'q'

# %%
labels=["Young Adult","Adult,"Middle-aged","senior"]
d["age-group"]=pd.qcut(df["age"],q=4,labels=labels)
# Out:
#   Cell In[22], line 1
#     labels=["Young Adult","Adult,"Middle-aged","senior"]
#                                                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
labels=["Young Adult","Adult","Middle-aged","senior"]
d["age-group"]=pd.cut(df["age"],q=4,labels=labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 labels=["Young Adult","Adult","Middle-aged","senior"]
# ----> 2 d["age-group"]=pd.cut(df["age"],q=4,labels=labels)
#
# TypeError: cut() got an unexpected keyword argument 'q'

# %%
labels=["Young Adult","Adult","Middle-aged","senior"]
d["age-group"]=pd.qcut(df["age"],q=4,labels=labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 labels=["Young Adult","Adult","Middle-aged","senior"]
# ----> 2 d["age-group"]=pd.qcut(df["age"],q=4,labels=labels)
#
# NameError: name 'd' is not defined

# %%
labels=["Young Adult","Adult',"Middle-aged","senior"]
df["age-group"]=pd.qcut(df["age"],q=4,labels=labels)
# Out:
#   Cell In[25], line 1
#     labels=["Young Adult","Adult',"Middle-aged","senior"]
#                                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
 labels=["Young Adult","Adult","Middle-aged","senior"]
df["age-group"]=pd.qcut(df["age"],q=4,labels=labels)
# Out:
#   Cell In[26], line 1
#     labels=["Young Adult","Adult","Middle-aged","senior"]
#     ^
# IndentationError: unexpected indent

# %%
labels=["Young Adult","Adult',"Middle-aged","senior"]
df["age-group"]=pd.qcut(df["age"],q=4,labels=labels)
# Out:
#   Cell In[27], line 1
#     labels=["Young Adult","Adult',"Middle-aged","senior"]
#                                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
labels=["Young Adult","Adult","Middle-aged","senior"]
df["age-group"]=pd.qcut(df["age"],q=4,labels=labels)

# %%
df[["age","age_group"]].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df[["age","age_group"]].head(10)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
df[['age','age_group']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df[['age','age_group']].head(10)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
df[['age',"age_group"]].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[['age',"age_group"]].head(10)
#
# NameError: name 'df' is not defined

# %%
df[['age',"age_group"]].head(10)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df[['age',"age_group"]].head(10)
#       2 df
#
# NameError: name 'df' is not defined

# %%
frequency_mapping = {
    "Fortnighty" : 14,
    "Weekly": 7,
    "Montly":30,
    "Quartely":90,
    "Annually" : 365,
    "Every 3 Months":990
}
df['purchase_frequency_days']=df['frequency_of_purchases'].map(frequency_mapping)

# %%
df['frequency_of_purchases'].map(frequency_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df['frequency_of_purchases'].map(frequency_mapping)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv("customer_shopping_behavior.csv")
df.head
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("customer_shopping_behavior.csv")
#       3 df.head
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv("customer_shopping_behavior.xlsx")
df.head
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("customer_shopping_behavior.xlsx")
#       3 df.head
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.virtual_documents',
#  '.vscode',
#  '24a31a4647',
#  'add.py',
#  'app.py',
#  'AppData',
#  'Application Data',
#  'audio',
#  'audio.py',
#  'Contacts',
#  'Cookies',
#  'Customer_Shopping_Behavior_Analysis.ipynb',
#  'Documents',
#  'Downloads',
#  'Dropbox',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TM.blf',
#  'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'tcs',
#  'Templates',
#  'Untitled-1.powerbi.txt',
# ...

# %%
import pandas as pd
df=pd.read_csv('Customer_Shopping_Behavior_Analysis.ipynb')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('Customer_Shopping_Behavior_Analysis.ipynb')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df=pd.read_csv('Customer_Shopping_Behavior_Analysis.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('Customer_Shopping_Behavior_Analysis.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\suren
# ['.anaconda', '.conda', '.continuum', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.virtual_documents', '.vscode', '24a31a4647', 'add.py', 'app.py', 'AppData', 'Application Data', 'audio', 'audio.py', 'Contacts', 'Cookies', 'Customer_Shopping_Behavior_Analysis.ipynb', 'Documents', 'Downloads', 'Dropbox', 'Favorites', 'Links', 'Local Settings', 'Microsoft', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TM.blf', 'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{362b1d03-15a2-11f0-be6c-706871307692}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'tcs', 'Templates', 'Untitled-1.powerbi.txt', 'Untitled-1.txt', 'Untitled.ipynb', 'Videos', 'vscode projects', 'WPS Cloud Files', 'WPSDrive']

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\suren\Downloads\Customer_Shopping_Behavior.csv")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\suren\Downloads\Customer_Shopping_Behavior.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
frequency_mapping = {
    "Fortnighty" : 14,
    "Weekly": 7,
    "Montly":30,
    "Quartely":90,
    "Annually" : 365,
    "Every 3 Months":990
}
df['purchase_frequency_days']=df['frequency_of_purchases'].map(frequency_mapping)

# %%
df['frequency_of_purchases'].map(frequency_mapping)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'frequency_of_purchases'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...

# %%
df[['frequency_of_purchases_days','frequency_of_purchases']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df[['frequency_of_purchases_days','frequency_of_purchases']].head(10)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df[['purchase_frequency_days','frequency_of_purchases']].head(10)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
frequency_mapping = {
    "Fortnighty" : 14,
    "Weekly": 7,
    "Montly":30,
    "Quartely":90,
    "Annually" : 365,
    "Every 3 Months":990
}
df['purchase_frequency_days']=df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df[['purchase_frequency_days','frequency_of_purchases']].head(10)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
df[['discount_applied','promo_code-used']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df[['discount_applied','promo_code-used']].head(10)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 18.6 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
# Replace placeholders with your actual details

username = "postgres"      # default user
password = "Surendar@1"      # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "customer behavior"   # the database you created in pgAdmin

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# Step 2: Load DataFrame into PostgreSQL
table_name = "customer"    # choose any table name

df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 10
#       7 port = "5432"              # default PostgreSQL port
#       8 database = "customer behavior"   # the database you created in pgAdmin
# ---> 10 engine = create_engine(
#      11     f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
#      12 )
#      14 # Step 2: Load DataFrame into PostgreSQL
#      15 table_name = "customer"    # choose any table name
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
# ...

# %%
import sys
# !{sys.executable} -m pip install psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import psycopg2
print("psycopg2 installed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 import psycopg2
#       2 print("psycopg2 installed successfully!")
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\python.exe

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:Surendar%401@localhost:5432/customer behavior"
)

df.to_sql(
    "customer_shopping",
    engine,
    if_exists="replace",
    index=False
)

print("Data imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       1 from sqlalchemy import create_engine
#       3 engine = create_engine(
#       4     "postgresql+psycopg2://postgres:Surendar%401@localhost:5432/customer behavior"
#       5 )
# ----> 7 df.to_sql(
#       8     "customer_shopping",
#       9     engine,
#      10     if_exists="replace",
#      11     index=False
#      12 )
#      14 print("Data imported successfully!")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\suren\Downloads\customer_shopping_behavior.csv")

print(df.head())
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:Surendar%401@localhost:5432/customer behavior"
)

df.to_sql(
    "customer_shopping",
    engine,
    if_exists="replace",
    index=False
)

print("Data imported successfully!")
# Out:
# Data imported successfully!

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv("customer_shopping_behavior.csv")

engine = create_engine(
    "postgresql+psycopg2://postgres:Surendar%401@localhost:5432/customer behavior"
)

df.to_sql(
    "customer_shopping_behavior",
    engine,
    if_exists="replace",
    index=False
)

print("Imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pandas as pd
#       2 from sqlalchemy import create_engine
# ----> 4 df = pd.read_csv("customer_shopping_behavior.csv")
#       6 engine = create_engine(
#       7     "postgresql+psycopg2://postgres:Surendar%401@localhost:5432/customer behavior"
#       8 )
#      10 df.to_sql(
#      11     "customer_shopping_behavior",
#      12     engine,
#      13     if_exists="replace",
#      14     index=False
#      15 )
#
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:Surendar%401@localhost:5432/customer behavior"
)

df.to_sql(
    "customer_shopping_behavior",
    engine,
    if_exists="replace",
    index=False
)

print("Imported successfully!")
# Out:
# Imported successfully!

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...
